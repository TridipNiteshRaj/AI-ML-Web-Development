# %%
 #plt.scatter(x, y, color='color-name', marker='marker-symbol', s=size-value, label='label-name')
import matplotlib.pyplot as plt

hours_studied = [1, 2, 3, 4, 5, 6, 7, 8]
exam_scores = [50, 55, 65, 70, 75, 80, 85, 90]

#scatter plot
plt.scatter(hours_studied, exam_scores, color='red', marker='*', s=100, label='Student Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.title('Hours Studied vs Exam Scores')
plt.legend(loc='lower right', fontsize=10)
plt.grid(color='lightgrey', linestyle='--', linewidth=0.5)
plt.show()

# %%
 #plt.scatter(x, y, color='color-name', marker='marker-symbol', s=size-value, label='label-name')
import matplotlib.pyplot as plt

# hours_studied = [1, 2, 3, 4, 5, 6, 7, 8]
# exam_scores = [50, 55, 65, 70, 75, 80, 85, 90]

#scatter plot
plt.scatter([1,2,3], [50,60,70], color='red', label='Class A')
plt.scatter([1,2,3], [45,55,65], color='blue', label='Class B')


plt.xlabel('Hours Studied')
plt.ylabel('Exam Scores')
plt.title('Hours Studied vs Exam Scores')
plt.legend(loc='lower right', fontsize=10)
plt.grid(color='lightgrey', linestyle='--', linewidth=0.5)
plt.show()
